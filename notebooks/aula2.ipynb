# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("../data/Densidade radial.txt") as file:
    print(file.read())
# Out:
# 0.0000 13088.5000
# 87.2500 13086.8424
# 174.5000 13081.8697
# 261.7500 13073.5818
# 349.0000 13061.9787
# 436.2500 13047.0605
# 523.5000 13028.8271
# 610.7500 13007.2786
# 698.0000 12982.4149
# 785.2500 12954.2360
# 872.5000 12922.7420
# 959.7500 12887.9328
# 1047.0000 12849.8084
# 1134.2500 12808.3689
# 1221.5000 12763.6143
# 1221.5000 12166.3319
# 1472.4444 12026.6007
# 1723.3889 11863.6736
# 1974.3333 11675.5238
# 2225.2778 11460.1242
# 2476.2222 11215.4480
# 2727.1667 10939.4683
# 2978.1111 10630.1580
# 3229.0556 10285.4904
# 3480.0000 9903.4384
# 3480.0000 5566.5000
# 3500.0000 5556.4000
# 3600.0000 5506.4000
# 3700.0000 5456.6000
# 3800.0000 5406.8000
# 3900.0000 5357.1000
# 4000.0000 5307.3000
# 4100.0000 5257.3000
# 4200.0000 5207.2000
# 4300.0000 5156.7000
# 4400.0000 5105.9000
# 4500.0000 5054.7000
# 4600.0000 5003.0000
# 4700.0000 4950.8000
# 4800.0000 4897.9000
# 4900.0000 4844.3000
# 5000.0000 4789.9000
# 5100.0000 4734.6000
# 5200.0000 4678.5000
# 5300.0000 4621.3000
# ...

# %%
raio, densidade = np.loadtxt("../data/Densidade radial.txt", unpack=True)
print(raio)
print(densidade)
# Out:
# [   0.       87.25    174.5     261.75    349.      436.25    523.5
#   610.75    698.      785.25    872.5     959.75   1047.     1134.25
#  1221.5    1221.5    1472.4444 1723.3889 1974.3333 2225.2778 2476.2222
#  2727.1667 2978.1111 3229.0556 3480.     3480.     3500.     3600.
#  3700.     3800.     3900.     4000.     4100.     4200.     4300.
#  4400.     4500.     4600.     4700.     4800.     4900.     5000.
#  5100.     5200.     5300.     5400.     5500.     5600.     5701.
#  5701.     5800.     5900.     5971.     5971.     6000.     6100.
#  6151.     6151.     6200.     6300.     6346.6    6346.6    6356.
#  6356.     6368.     6368.     6371.    ]
# [13088.5    13086.8424 13081.8697 13073.5818 13061.9787 13047.0605
#  13028.8271 13007.2786 12982.4149 12954.236  12922.742  12887.9328
#  12849.8084 12808.3689 12763.6143 12166.3319 12026.6007 11863.6736
#  11675.5238 11460.1242 11215.448  10939.4683 10630.158  10285.4904
# ...

# %%
plt.plot(raio, densidade)
plt.xlabel("Raio (km)")
plt.ylabel("Densidade (kg/m³)")
# Out:
# Text(0, 0.5, 'Densidade (kg/m³)')

# %%
plt.plot(raio, densidade)
plt.xlabel("Raio (km)")
plt.ylabel("Densidade (kg/m³)")
plt.grid()

# %% [markdown]
# Calulando número de Rayleigh

# %%
density = 4000
gravity = 10
alpha = 3.0e-5
dt = 2000
b = 700000
mu = 1.0e21
kappa = 1.0e-6

# %%
ra = density*gravity*alpha*dt*b**3 /(mu*kappa)
ra
# Out:
# 823200.0
