# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,10,101)
y = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y, label="sin")
plt.plot(x, y2, label="cos")

plt.legend()
plt.xlabel("x")

plt.ylabel("y")
plt.grid()
