# %% [markdown]
# # Difusão 2D

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dx = 2000.0
litosphere_depth = 1250000.0
T_BASE_LITOSPHERE = 1300.0

x = np.arange(0.0, 1.5e6, dx)
z = np.arange(0.0, litosphere_depth, dx)


X,Z = np.meshgrid(x,z)

# %%
# Beta: Espessura inicial / espessura final
beta_max = 3.0
beta = np.ones_like(x)

# %%
# Making the "ramp"
beta[x>700e3] = beta_max
cond = (x>=500e3)&(x<=700e3)
beta[cond] = ((x[cond]-500e3)/200e3)*(beta_max-1.0)+1.0

plt.plot(x,beta)
